# %%
import numpy as np
from loss_acc_plot import loss_acc_plot

# %%
his = np.load('result-CELEB_FORMAT128_20CLASS_20PERCENT.npy', allow_pickle=True, encoding='latin1').item()

# %%
len(his['acc'])
# Out:
# 360

# %%
loss_acc_plot(his, 60, 300, False, True)
